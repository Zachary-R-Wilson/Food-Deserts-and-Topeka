# %%
import pandas as pd

# %%
df = pd.read_csv("cleaning_Census.csv")
df
# Out:
#       moe                        name  Geocode  value  Unnamed: 4
# 0    4159         Smith County Kansas    20183  43438         NaN
# 1    9500         Grant County Kansas    20067  55455         NaN
# 2    3993       Kingman County Kansas    20095  58483         NaN
# 3    4415        Nemaha County Kansas    20131  58644         NaN
# 4    4688  Pottawatomie County Kansas    20149  64657         NaN
# ..    ...                         ...      ...    ...         ...
# 100  5471          Rush County Kansas    20165  40598         NaN
# 101  3013        Marion County Kansas    20115  51262         NaN
# 102  5974        Ottawa County Kansas    20143  51971         NaN
# 103  5019        Barber County Kansas    20007  50613         NaN
# 104  3545     Dickinson County Kansas    20041  48167         NaN
#
# [105 rows x 5 columns]
