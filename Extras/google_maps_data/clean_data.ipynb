# %%
import pandas as pd

# %%
csv_list=['bakery.csv','home_goods_store.csv','supermarket.csv',
'bank.csv','convenience_store.csv','liquor_store.csv',
'bar.csv','department_store.csv','restaurant.csv',
'cafe.csv','drugstore.csv', 'store.csv'
]

# %%
df = pd.read_csv(csv_list[0])
df.drop(inplace = True,columns="Unnamed: 0")

# %%
df.drop_duplicates(inplace = True,ignore_index=True)
df
# Out:
#                                Name  \
# 0   Mad Eliza's Cakes & Confections
# 1                 Sam's Club Bakery
# 2               Cold Stone Creamery
# 3                 Smallcakes Topeka
# 4                      Panera Bread
# 5                    Walmart Bakery
# 6       Perkins Restaurant & Bakery
# 7                 Bakers Dozen 17th
# 8                  Cookies by Gayla
# 9                   Cookie Boutique
# 10               Kan You Say Oh Yum
# 11                 Le Petit Bon Bon
# 12                   Dillons Bakery
# 13         Pizagel's Pizza & Bakery
# 14                   Baskin-Robbins
# 15                  Daylight Donuts
# 16                   Dillons Bakery
# 17                Baking Traditions
# 18                     Schlotzsky's
# 19                          Dunkin'
# 20         Baker's Dozen 6th Street
# 21                   Walmart Bakery
# 22                 Josey Baking Co.
# 23          Simply Sarah's Catering
# 24                  Paradise Donuts
# 25      Roxie's Donut Dive & Coffee
# 26                  Bimbo Baking Co
# 27                   Walmart Bakery
# 28                     Schlotzsky's
# 29                 Scooter's Coffee
# 30                   Walmart Bakery
# 31                       Shana Cake
# 32                  Daylight Donuts
# 33                 El Torito Topeka
# 34            Paradise Donuts North
# 35       Baker's Dozen Donuts North
# 36          Panderia Reynosa Bakery
# 37                   Baskin-Robbins
# 38                   Walmart Bakery
# 39                   Marlene Bakery
# 40              Panaderia Monterrey
#
#                                           Address   Latitude  Longitude
# 0                                          Topeka  39.001626 -95.782089
# 1           1401 Southwest Wanamaker Road, Topeka  39.041499 -95.764625
# 2   1227 Southwest Wanamaker Road Ste 100, Topeka  39.044995 -95.763936
# 3      1223 Southwest Wanamaker Road #300, Topeka  39.044989 -95.762344
# 4           1421 Southwest Wanamaker Road, Topeka  39.040923 -95.762263
# 5           1501 Southwest Wanamaker Road, Topeka  39.039819 -95.764546
# 6           1720 Southwest Wanamaker Road, Topeka  39.035183 -95.761539
# 7         5938 Southwest 17th Street #400, Topeka  39.036992 -95.760143
# 8           1801 Southwest Wanamaker Road, Topeka  39.032459 -95.765771
# 9                                          Topeka  39.032059 -95.766279
# 10             5745 Southwest 69th Street, Auburn  38.941955 -95.757026
# 11            835 Southwest Fairlawn Road, Topeka  39.053254 -95.743711
# 12              5315 Southwest 22nd Place, Topeka  39.026514 -95.745121
# 13           2830 Southwest Fairlawn Road, Topeka  39.015234 -95.743405
# 14             4400 Southwest 21st Street, Topeka  39.030025 -95.730657
# 15             4201 Southwest 21st Street, Topeka  39.029141 -95.728050
# 16             4015 Southwest 10th Avenue, Topeka  39.050694 -95.727504
# 17          4036 Southwest Huntoon Street, Topeka  39.044173 -95.726794
# 18          2019 Southwest Gage Boulevard, Topeka  39.030553 -95.725931
# 19             4009 Southwest 21st Street, Topeka  39.029185 -95.726963
# 20              2601 Southwest 6th Avenue, Topeka  39.058340 -95.707385
# 21          335 Southwest Macvicar Avenue, Topeka  39.059913 -95.708349
# 22          3119 Southwest Huntoon Street, Topeka  39.043794 -95.716254
# 23             1518 Southwest 41st Street, Topeka  38.995713 -95.698132
# 24              1620 Southwest 6th Avenue, Topeka  39.057931 -95.695388
# 25          1440 Southwest Huntoon Street, Topeka  39.044756 -95.696291
# 26        4100 Southwest Martin Drive # 1, Topeka  38.994537 -95.696527
# 27             1301 Southwest 37th Street, Topeka  38.998848 -95.694355
# 28            400 Southwest 29th Street Z, Topeka  39.016168 -95.686978
# 29        2909 Southwest Topeka Boulevard, Topeka  39.013795 -95.688059
# 30          2600 Northwest Rochester Road, Topeka  39.093696 -95.671762
# 31                435 South Kansas Avenue, Topeka  39.053377 -95.672933
# 32           1001 Southeast Quincy Street, Topeka  39.045443 -95.674695
# 33        3000 Northwest Topeka Boulevard, Topeka  39.100584 -95.663036
# 34        2037 Northwest Topeka Boulevard, Topeka  39.087109 -95.665434
# 35        1949 Northwest Topeka Boulevard, Topeka  39.084693 -95.666032
# 36           1200 Northeast Seward Avenue, Topeka  39.059043 -95.654268
# 37       2837 Southeast California Avenue, Topeka  39.015386 -95.652126
# 38       2630 Southeast California Avenue, Topeka  39.020591 -95.648508
# 39           1925 Northeast Seward Avenue, Topeka  39.058632 -95.644949
# 40              3154 Southeast 6th Avenue, Topeka  39.045602 -95.635217

# %%
df.to_csv("../no_dup/" + csv_list[0])
