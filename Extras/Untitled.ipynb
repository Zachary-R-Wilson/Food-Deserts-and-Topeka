# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/Income by Location.csv")
df
# Out:
#      ID Year  Year  ID Race   Race  Household Income by Race  \
# 0       2017  2017        0  Total                     30675
# 1       2017  2017        0  Total                     48500
# 2       2017  2017        0  Total                     25489
# 3       2017  2017        0  Total                     18559
# 4       2017  2017        0  Total                     26000
# ..       ...   ...      ...    ...                       ...
# 210     2013  2013        0  Total                     40329
# 211     2013  2013        0  Total                     33433
# 212     2013  2013        0  Total                     27224
# 213     2013  2013        0  Total                     23164
# 214     2013  2013        0  Total                     21639
#
#      Household Income by Race Moe  Geography        ID Geography
# 0                          6426.0      16.03  14000US20177001603
# 1                          7503.0      41.00  14000US20177004100
# ...

# %%
tracts = [27.02,
26.02,
26.01,
24,
25,
27.01,
16.02,
16.01,
19,
41,
22,
21,
18,
28,
15,
4,
5,
6,
40,
29,
10,
11,
12,
13,
30.01,
31]

# %%
i=0
if df["Year"][i] == 2017:
    df2.append(df[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-d085ebfa3407> in <module>
#       1 i=0
#       2 if df["Year"][i] == 2017:
# ----> 3     df2.append(df[i])
#
# AttributeError: 'numpy.int64' object has no attribute 'append'

# %%
df2
# Out:
# 2017
