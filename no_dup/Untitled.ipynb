# %%
import pandas as pd
csv_list=['bakery.csv','home_goods_store.csv','supermarket.csv',
'convenience_store.csv','liquor_store.csv',
'department_store.csv','restaurant.csv',
'cafe.csv','drugstore.csv', 'store.csv'
]
table_list=['bakery','home_goods_store','supermarket',
'convenience_store','liquor_store',
'department_store','restaurant',
'cafe','drugstore', 'store'
]

# %%
names = []
addresses = []
lats = []
lngs = []
csv_name = []
master_df = pd.DataFrame({
    "Name": names,
    "Address": addresses,
    "Latitude": lats,
    "Longitude": lngs,
    "Table Name":csv_name
})

# %%
for i in range(10):
    df = pd.read_csv(csv_list[i])
    df.drop(inplace = True,columns="Unnamed: 0")
    df["Table Name"] = table_list[i]
    master_df = master_df.append(df,ignore_index=True)

master_df.drop_duplicates(inplace = True, ignore_index=True)
master_df
# Out:
#                                  Name  \
# 0     Mad Eliza's Cakes & Confections
# 1                   Sam's Club Bakery
# 2                 Cold Stone Creamery
# 3                   Smallcakes Topeka
# 4                        Panera Bread
# ...                               ...
# 1880    Nail Benders Home Improvement
# 1881                       Canvas Man
# 1882                  Rees Fruit Farm
# 1883    Bernadette's Custom Cosmetics
# 1884                 Kansas Drug Card
#
#                                             Address   Latitude  Longitude  \
# 0                                            Topeka  39.001626 -95.782089
# 1             1401 Southwest Wanamaker Road, Topeka  39.041499 -95.764625
# 2     1227 Southwest Wanamaker Road Ste 100, Topeka  39.044995 -95.763936
# 3        1223 Southwest Wanamaker Road #300, Topeka  39.044989 -95.762344
# 4             1421 Southwest Wanamaker Road, Topeka  39.040923 -95.762263
# ...                                             ...        ...        ...
# 1880           3925 Southeast 77th Street, Berryton  38.927405 -95.606345
# 1881             2730 Northeast 35th Street, Topeka  39.110223 -95.595987
# 1882                          2476 Kansas 4, Topeka  39.091186 -95.594169
# 1883            2521 Southeast Cuvier Drive, Topeka  39.020586 -95.595004
# 1884             4536 Southeast 37th Street, Topeka  39.000583 -95.595594
#
#       Table Name
# 0     bakery.csv
# 1     bakery.csv
# 2     bakery.csv
# 3     bakery.csv
# 4     bakery.csv
# ...          ...
# 1880   store.csv
# 1881   store.csv
# 1882   store.csv
# 1883   store.csv
# 1884   store.csv
#
# [1885 rows x 5 columns]

# %%
master_df.to_csv("../Resources/master.csv")

# %%
import censusgeocode as cg
import pandas as pd 
import time

# %%
csv_list=['bakery.csv','home_goods_store.csv','supermarket.csv',
'convenience_store.csv','liquor_store.csv',
'department_store.csv','restaurant.csv',
'cafe.csv','drugstore.csv', 'store.csv']

df = pd.read_csv(csv_list[0])
result_list = []
for j in range(df.shape[0]):
    try:
        result = cg.coordinates(x=df["Longitude"][j], y=df["Latitude"][j])
        spl_re = result['Census Tracts'][0]['NAME']
        spl_re = spl_re.split(' ')
        result_list.append(spl_re[2])
    except:
        result_list.append("Nan")
    time.sleep(1)

# %%
df["Tract"] = result_list
df
# Out:
#     Unnamed: 0                             Name  \
# 0            0  Mad Eliza's Cakes & Confections
# 1            1                Sam's Club Bakery
# 2            2              Cold Stone Creamery
# 3            3                Smallcakes Topeka
# 4            4                     Panera Bread
# 5            5                   Walmart Bakery
# 6            6      Perkins Restaurant & Bakery
# 7            7                Bakers Dozen 17th
# 8            8                 Cookies by Gayla
# 9            9                  Cookie Boutique
# 10          10               Kan You Say Oh Yum
# 11          11                 Le Petit Bon Bon
# 12          12                   Dillons Bakery
# 13          13         Pizagel's Pizza & Bakery
# 14          14                   Baskin-Robbins
# 15          15                  Daylight Donuts
# 16          16                   Dillons Bakery
# 17          17                Baking Traditions
# 18          18                     Schlotzsky's
# 19          19                          Dunkin'
# 20          20         Baker's Dozen 6th Street
# 21          21                   Walmart Bakery
# 22          22                 Josey Baking Co.
# 23          23          Simply Sarah's Catering
# 24          24                  Paradise Donuts
# 25          25      Roxie's Donut Dive & Coffee
# 26          26                  Bimbo Baking Co
# 27          27                   Walmart Bakery
# 28          28                     Schlotzsky's
# 29          29                 Scooter's Coffee
# 30          30                   Walmart Bakery
# 31          31                       Shana Cake
# 32          32                  Daylight Donuts
# 33          33                 El Torito Topeka
# 34          34            Paradise Donuts North
# 35          35       Baker's Dozen Donuts North
# 36          36          Panderia Reynosa Bakery
# 37          37                   Baskin-Robbins
# 38          38                   Walmart Bakery
# 39          39                   Marlene Bakery
# 40          40              Panaderia Monterrey
#
#                                           Address   Latitude  Longitude  Tract
# 0                                          Topeka  39.001626 -95.782089  36.04
# 1           1401 Southwest Wanamaker Road, Topeka  39.041499 -95.764625  36.07
# 2   1227 Southwest Wanamaker Road Ste 100, Topeka  39.044995 -95.763936  24.01
# 3      1223 Southwest Wanamaker Road #300, Topeka  39.044989 -95.762344  24.01
# 4           1421 Southwest Wanamaker Road, Topeka  39.040923 -95.762263  36.07
# 5           1501 Southwest Wanamaker Road, Topeka  39.039819 -95.764546  36.07
# 6           1720 Southwest Wanamaker Road, Topeka  39.035183 -95.761539  26.02
# 7         5938 Southwest 17th Street #400, Topeka  39.036992 -95.760143  26.02
# 8           1801 Southwest Wanamaker Road, Topeka  39.032459 -95.765771  36.07
# 9                                          Topeka  39.032059 -95.766279  36.07
# 10             5745 Southwest 69th Street, Auburn  38.941955 -95.757026  39.02
# 11            835 Southwest Fairlawn Road, Topeka  39.053254 -95.743710  24.02
# 12              5315 Southwest 22nd Place, Topeka  39.026514 -95.745121  26.01
# 13           2830 Southwest Fairlawn Road, Topeka  39.015234 -95.743405  27.01
# 14             4400 Southwest 21st Street, Topeka  39.030025 -95.730657     25
# 15             4201 Southwest 21st Street, Topeka  39.029140 -95.728050  27.01
# 16             4015 Southwest 10th Avenue, Topeka  39.050694 -95.727504  24.01
# 17          4036 Southwest Huntoon Street, Topeka  39.044173 -95.726794  24.01
# 18          2019 Southwest Gage Boulevard, Topeka  39.030553 -95.725931  27.01
# 19             4009 Southwest 21st Street, Topeka  39.029185 -95.726963  27.01
# 20              2601 Southwest 6th Avenue, Topeka  39.058340 -95.707385     21
# 21          335 Southwest Macvicar Avenue, Topeka  39.059913 -95.708349     41
# 22          3119 Southwest Huntoon Street, Topeka  39.043794 -95.716254     19
# 23             1518 Southwest 41st Street, Topeka  38.995713 -95.698132  37.01
# 24              1620 Southwest 6th Avenue, Topeka  39.057931 -95.695388     22
# 25          1440 Southwest Huntoon Street, Topeka  39.044756 -95.696291      4
# 26        4100 Southwest Martin Drive # 1, Topeka  38.994537 -95.696527  37.01
# 27             1301 Southwest 37th Street, Topeka  38.998848 -95.694355     28
# 28            400 Southwest 29th Street Z, Topeka  39.016168 -95.686978     15
# 29        2909 Southwest Topeka Boulevard, Topeka  39.013795 -95.688059     28
# 30          2600 Northwest Rochester Road, Topeka  39.093696 -95.671762      7
# 31                435 South Kansas Avenue, Topeka  39.053377 -95.672933     40
# 32           1001 Southeast Quincy Street, Topeka  39.045443 -95.674695     40
# 33        3000 Northwest Topeka Boulevard, Topeka  39.100584 -95.663036  33.01
# 34        2037 Northwest Topeka Boulevard, Topeka  39.087109 -95.665433      7
# 35        1949 Northwest Topeka Boulevard, Topeka  39.084693 -95.666032      7
# 36           1200 Northeast Seward Avenue, Topeka  39.059043 -95.654268     10
# 37       2837 Southeast California Avenue, Topeka  39.015386 -95.652126     13
# 38       2630 Southeast California Avenue, Topeka  39.020591 -95.648508     31
# 39           1925 Northeast Seward Avenue, Topeka  39.058632 -95.644949     10
# 40              3154 Southeast 6th Avenue, Topeka  39.045602 -95.635217     11

# %%
df.to_csv("../Resources/Baking.csv")
